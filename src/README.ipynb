# %% [markdown]
# [ja]: #
# # はじめに
#
# [en]: #
# # Introduction
#
# [zh]: #
# # 介绍

# %% [markdown]
# [ja]: #
# この教材 RC bootcampはリザバー計算 (Reservoir computing; RC)の入門用に作成されています。
# 特にRCの分野で登場する概念や手法を、初心者でも素早く習得できるように様々な章が用意されています。
#
# [en]: #
# This RC bootcamp is designed as an introduction to reservoir computing (RC).
# It provides various chapters to help beginners quickly learn the key concepts and techniques in the field.
#
# [zh]: #
# 该 RC 训练营旨在介绍储池计算。它提供了各个章节来帮助初学者快速学习该领域的关键概念和技术。

# %% [markdown]
# [ja]: #
# ## Jupyter Notebook
#
# [en]: #
# ## Jupyter Notebook
#
# [zh]: #
# ## Jupyter 笔记本

# %% [markdown]
# [ja]: #
# この教材ではプログラミング言語の一種であるPythonを使用します。
# またより長期的にはJupyter Notebookを用いて、インタラクティブに実験を実装する手法の習得を目指します。
# 以下、設定・実行方法を難易度順に代表的なものを記載します。
# お好きな方法でセットアップしてください。
#
# [en]: #
# This material uses Python as the programming language.
# In the long run, we aim to help you master interactive experimentation using Jupyter Notebooks.
# Below are representative setup and execution methods listed in order of difficulty.
# Please choose your preferred method for setup.
#
# [zh]: #
# 本材料使用 Python 作为编程语言。从长远来看，我们的目标是帮助您掌握使用 Jupyter Notebooks 进行交互式实验。以下是按难度顺序列出的代表性设置和执行方法。请选择您首选的设置方法。

# %% [markdown]
# [ja]: #
# ### 方法1: Google Colaboratory (+ Google Drive) (難易度: 初級)
#
# [en]: #
# ### Method 1: Google Colaboratory (+ Google Drive) (Beginner)
#
# [zh]: #
# ### 方法 1：Google Colaboratory (+ Google Drive)(初学者)

# %% [markdown]
# [ja]: #
# Google Colaboratory (Colab) はJupyter Notebookのフロントエンドインターフェースです。
# ブラウザ上で完結し、かつ主要なパッケージ (`numpy`、`matplotlib`等) はインストール済みなので特別な設定は特に必要なく、 **プログラミング未経験者におすすめできる** 方法です。
# また必要に応じて **Google Drive上にノートブックを保存** できるので、あとからコードや実行結果を確認できます。
# 一方で計算リソースが無料版だと限定的な点、時間が経過するとインスタンスがシャットダウンしてしまう点から、ある程度慣れたら **以降に紹介するローカルで実行する方法の導入を推奨します**。
#
# 0. Googleのアカウントが必要ですので用意してください。
# 1. https://rc-bootcamp.github.io/ja/ から学びたい章を選び、Colabのアイコンをクリックしてください。Colabが起動します。
#
# Google Drive上でColabを開きたい場合以下の手順を踏んでください。
#
# 2. `drive.mount("/content/gdrive")`と書かれているセルについて、`save_to_drive`を`True`に変更してください (チェックボックスをクリック)。また必要に応じてGoogle Driveのパスも変更してください (`project_path`の変更)
# 3. 上記のセルを実行すると、認証のポップアップが表示されるので許可してください。これでGoogle Driveのディレクトリに保存されます。
# 4. [Google Drive](https://drive.google.com)上に保存されたノートブックを開いてください。デフォルトではGoogle Driveのルートディレクトリ以下に`rc-bootcamp...`というフォルダができているはずで、その中にすべてのノートブックがコピーされているはずです。
# 5. 対象のノートブックを開き、同様に`save_to_drive`と`project_path`を変更してください。ランタイムの起動のたびに認証が同様に必要ですが、これでGoogle Drive上でノートブックを編集して実行できるようになります。
#
# [en]: #
# Google Colaboratory is a browser-based Jupyter Notebook frontend suitable for beginners.
# No additional setup is required beyond a Google account, as essential packages (e.g., `numpy`, `matplotlib`) are preinstalled.
# Additionally, you can save your notebooks to Google Drive to review your code and results later.
# Note that free-tier resources are limited and sessions may time out after periods of inactivity. Therefore, we recommend transitioning to a local environment once you become familiar with the basics.
#
# 0. Create or sign in to your Google account.
# 1. Visit https://rc-bootcamp.github.io/ and select the chapter you want to learn, then click the Colab icon to launch the notebook.
#
# To save and sync your progress with Google Drive, follow these steps:
#
# 2. Locate the configuration cell, check the `save_to_drive` box (set to `True`), and adjust the `project_path` if you wish to use a specific folder.
# 3. Run the cell and follow the on-screen prompts to authorize access. This enables the notebook to save data directly to your Drive.
# 4. Once the setup is complete, go to [Google Drive](https://drive.google.com) and find the project folder (e.g., `rc-bootcamp...`). All necessary files and notebooks will be available there.
# 5. Open the notebook from your Drive. Remember to set `save_to_drive` to `True` and adjust the `project_path` as needed, then authenticate each time you start a new session to ensure your changes are saved.
#
# [zh]: #
# Google Colaboratory 是一个基于浏览器的 Jupyter Notebook 前端，适合初学者。除了 Google 帐户之外，无需进行任何其他设置，因为基本软件包(例如 `numpy`、`matplotlib`)已预先安装。此外，您可以将笔记本保存到 Google 云端硬盘，以便稍后查看代码和结果。请注意，免费套餐资源有限，并且会话在不活动一段时间后可能会超时。因此，我们建议您在熟悉基础知识后过渡到本地环境。
#
# 0. 创建或登录您的 Google 帐户。
# 1.访问https://rc-bootcamp.github.io/并选择您想要学习的章节，然后单击Colab图标启动笔记本。
#
# 要保存进度并与 Google 云端硬盘同步，请按照以下步骤操作：
#
# 2. 找到配置单元，选中 `save_to_drive` 框(设置为 `True`)，如果您希望使用特定文件夹，则调整 `project_path`。
# 3. 运行单元并按照屏幕上的提示授权访问。这使笔记本电脑能够将数据直接保存到您的云端硬盘。
# 4. 设置完成后，进入 [Google Drive](https://drive.google.com) 并找到项目文件夹(例如 `rc-bootcamp...`)。所有必要的文件和笔记本都可以在那里找到。
# 5. 从云端硬盘打开笔记本。请记住将 `save_to_drive` 设置为 `True` 并根据需要调整 `project_path`，然后在每次启动新会话时进行身份验证，以确保保存更改。
#
# [END]: #
# ---

# %% [markdown]
# [ja]: #
# ### 方法2: uv + VSCode (難易度: 中級)
#
# [en]: #
# ### Method 2: uv + VSCode (Competent)
#
# [zh]: #
# ### 方法2：uv + VSCode(胜任)

# %% [markdown]
# [ja]: #
# パッケージ管理ツール`uv`を用いて仮想環境を構築しVSCode上で実行する方法で、本格的に研究・開発を行う人におすすめする方法です。
# 汎用性が高くVSCodeの強力なパッケージの支援を受けられるので、初学者でも挑戦しても問題ないと思います (実際慣れればそこまで難しくないです)。
#
# [en]: #
# This method uses the package management tool `uv` to create a virtual environment and run it in VSCode.
# It is recommended for those who want to conduct research and development more seriously.
# Its versatility and robust VSCode extension support make it accessible even for beginners (it's not that difficult once you get used to it).
#
# [zh]: #
# 该方法使用包管理工具`uv`创建虚拟环境并在VSCode中运行。推荐给那些想要更认真地进行研发的人。它的多功能性和强大的 VSCode 扩展支持使其即使对于初学者也可以使用(一旦习惯了它就不会那么困难)。

# %% [markdown]
# [ja]: #
# #### Step 1: uvのインストール
#
# [en]: #
# #### Step 1: Installing uv
#
# [zh]: #
# #### 第 1 步：安装 uv

# %% [markdown]
# [ja]: #
# [`uv`](https://github.com/astral-sh/uv)はpythonのパッケージの管理ツールです。
# プロジェクト毎にパッケージをインストールできるだけでなく、そのパッケージのバージョンを記録するため配布にも活用できます (condaと似ていますがuvは極めて高速に動作します)。
# 詳細は[ドキュメント](https://docs.astral.sh/uv/getting-started/installation)の手順にしたがってインストールしてください。
# 以下最低限の手順を説明します。
#
# [en]: #
# [`uv`](https://github.com/astral-sh/uv) is a tool for managing Python packages.
# You can install packages on a per-project basis, and it can also be used for distribution by recording package versions (similar to conda, but uv is extremely fast).
# Follow the steps in the [documentation](https://docs.astral.sh/uv/getting-started/installation) to install it.
# Below are the minimum steps.
#
# [zh]: #
# [`uv`](https://github.com/astral-sh/uv)是一个管理Python包的工具。您可以按项目安装软件包，也可以通过记录软件包版本来用于分发(类似于 conda，但 uv 速度极快)。按照[文档](https://docs.astral.sh/uv/getting-started/installation)中的步骤进行安装。以下是最少的步骤。

# %% [markdown]
# [ja]: #
# ##### LinuxやMacOSの場合
#
# [en]: #
# ##### Linux and MacOS
#
# [zh]: #
# ##### Linux 和 MacOS

# %% [markdown]
# [ja]: #
# コンソールを開き、以下のコマンドでインストールできます。
# ```sh
# curl -LsSf https://astral.sh/uv/install.sh | sh
# ```
# インストールが完了したら
# ```sh
# uv help
# ```
# でインストールされているか確認してください。
#
# [en]: #
# Open your terminal and install it using the following command:
# ```sh
# curl -LsSf https://astral.sh/uv/install.sh | sh
# ```
# Then, check if it has been installed by executing:
# ```sh
# uv help
# ```
#
# [zh]: #
# 打开终端并使用以下命令安装它：
#
# ```sh
# curl -LsSf https://astral.sh/uv/install.sh | sh
# ```
#
# 然后，通过执行以下命令检查是否已安装：
#
# ```sh
# uv help
# ```

# %% [markdown]
# [ja]: #
# ##### Windowsの場合
#
# [en]: #
# ##### Windows
#
# [zh]: #
# ##### Windows

# %% [markdown]
# [ja]: #
# PowerShellを起動し (スタートメニューを開き、「Windows PowerShell」と入力し、Windows PowerShell が表示されるので起動できます。) 以下のコマンドでインストールできます。
# ```sh
# powershell -ExecutionPolicy ByPass -c "irm https://astral.sh/uv/install.ps1 | iex"
# ```
# インストールが完了したら、
# ```sh
# uv help
# ```
# でインストールされているか確認してください。
#
# [en]: #
# Open PowerShell (open the Start Menu, type "Windows PowerShell", and launch the Windows PowerShell application) and install using the following command:
# ```sh
# powershell -ExecutionPolicy ByPass -c "irm https://astral.sh/uv/install.ps1 | iex"
# ```
#
# Then, check if it has been installed by executing:
# ```sh
# uv help
# ```
#
# [zh]: #
# 打开 PowerShell(打开“开始”菜单，键入“Windows PowerShell”，然后启动 Windows PowerShell 应用程序)并使用以下命令进行安装：
#
# ```sh
# powershell -ExecutionPolicy ByPass -c "irm https://astral.sh/uv/install.ps1 | iex"
# ```
#
# 然后，通过执行以下命令检查是否已安装：
#
# ```sh
# uv help
# ```

# %% [markdown]
# [ja]: #
# #### Step 2: VSCodeの設定
#
# [en]: #
# #### Step 2: Configuring VSCode
#
# [zh]: #
# #### 第 2 步：配置 VSCode

# %% [markdown]
# [ja]: #
# [Visual Studio Code (VSCode)](https://code.visualstudio.com/)はMicrosoftが開発するクロスプラットフォームのIDEです。
# [インストーラ](https://code.visualstudio.com/download)をダウンロード＆実行してください。
# すると`code`コマンドが使用できるようになるので、対象のフォルダをドラッグするか、以下のコマンドで対象のディレクトリを開いてください (Windowsの場合はPowerShellを使ってください)。
#
# ```sh
# code PATH_TO_DIR
# ```
#
# VSCodeの特長はその拡張機能の豊富さです。
# 拡張機能は左側の`Extensions`タブよりインストールできます。
# 最低限のおすすめのパッケージは`.vscode/extensions.json`に記載しておきました。
# VSCodeの拡張機能のタブを開くとそのパッケージが表示されるので、クリックするだけでインストールできます。
#
# [en]: #
# [Visual Studio Code (VSCode)](https://code.visualstudio.com/) is a cross-platform IDE developed by Microsoft.
# Download and run the [installer](https://code.visualstudio.com/download).
# Once installed, you can use the `code` command to either drag the target folder into VSCode or open the directory from your terminal (use PowerShell on Windows):
#
# ```sh
# code PATH_TO_DIR
# ```
#
# One of VSCode's key features is its rich extension ecosystem.
# You can install extensions from the `Extensions` tab on the left.
# The minimum recommended packages are listed in `.vscode/extensions.json`.
# When you open the Extensions tab in VSCode, these packages will appear in the recommendations and can be installed with a single click.
#
# [zh]: #
# [Visual Studio Code (VSCode)](https://code.visualstudio.com/)是微软开发的跨平台IDE。
# Download and run the [installer](https://code.visualstudio.com/download).
# 安装后，您可以使用 `code` 命令将目标文件夹拖到 VSCode 中或从终端打开该目录(在 Windows 上使用 PowerShell)：
#
# ```sh
# code PATH_TO_DIR
# ```
#
# VSCode 的主要功能之一是其丰富的扩展生态系统。您可以从左侧的 `Extensions` 选项卡安装扩展。
# `.vscode/extensions.json` 中列出了推荐的最低软件包。当您在 VSCode 中打开“扩展”选项卡时，这些包将出现在推荐中，并且只需单击一下即可安装。

# %% [markdown]
# [ja]: #
# #### Step 3: 仮想環境の構築
#
# [en]: #
# #### Step 3: Creating the virtual environment
#
# [zh]: #
# #### 第 3 步：创建虚拟环境

# %% [markdown]
# [ja]: #
# フォルダをVSCodeで開くと左側にフォルダの中身の一覧が表示されます。
# `Ctrl+Shift+@`を押すと下画面にターミナルが開くと思います。
# そこで次のコマンドを入力して仮想環境を構築してください。
#
# ```sh
# uv sync
# ```
# `uv.lock`に書かれている情報をもとに、同じディレクトリの`.venv`と書かれたフォルダが作成され仮想環境が構築されます。
# 同時にこの教材で使われるPythonカーネルとPythonのパッケージが自動的にインストールされれます。
# 数分かかると思うので、インストールし終わったら起動し`Ctrl+Shft+p`を押し、`Python: Select Interpreter`から使うカーネル (今回は`.venv`)を指定します。
# `.ipynb`のカーネルも同様で、右上に表示されている`Select Kernel`から対象のPython Kernelを指定してください。
#
# なおVSCode以外でもLinuxかMacOSの場合はから以下のコマンドを実行すると仮想環境に入れます。
# ```sh
# source .venv/bin/activate
# ```
# Windowsの場合は以下のコマンドを実行してください。
# ```powershell
# .venv\Scripts\activate
# ```
#
# [en]: #
# When you open the folder in VSCode, the folder contents will appear on the left side.
# Press `Ctrl+Shift+@` to open a terminal at the bottom of the screen.
# Enter the following command to set up the virtual environment:
#
# ```sh
# uv sync
# ```
#
# Based on the information in `uv.lock`, a `.venv` folder will be created in the same directory and the virtual environment will be set up.
# The Python kernel and packages used in this material will be automatically installed.
# This may take a few minutes.
# Once installation is complete, press `Ctrl+Shift+P` and select `Python: Select Interpreter` to specify the kernel (`.venv` in this case).
# For `.ipynb` files, select the target Python kernel from `Select Kernel` in the upper right corner.
#
# If you are using Linux or macOS, you can enter the virtual environment by running the following command:
#
# ```sh
# source .venv/bin/activate
# ```
#
# For Windows, run the following command:
#
# ```powershell
# .venv\Scripts\activate
# ```
#
# [zh]: #
# 当您在 VSCode 中打开文件夹时，文件夹内容将显示在左侧。按 `Ctrl+Shift+@` 打开屏幕底部的终端。输入以下命令来设置虚拟环境：
#
# ```sh
# uv sync
# ```
#
# 根据`uv.lock`中的信息，将在同一目录中创建`.venv`文件夹并设置虚拟环境。本材料中使用的 Python 内核和软件包将自动安装。这可能需要几分钟。安装完成后，按 `Ctrl+Shift+P` 并选择 `Python: Select Interpreter` 指定内核(本例中为 `.venv`)。对于`.ipynb`文件，从右上角的`Select Kernel`中选择目标Python内核。
#
# 如果您使用的是Linux或macOS，可以通过运行以下命令进入虚拟环境：
#
# ```sh
# source .venv/bin/activate
# ```
#
# 对于 Windows，运行以下命令：
#
# ```powershell
# .venv\Scripts\activate
# ```

# %% [markdown]
# [ja]: #
# #### Step 4: その他VSCodeの設定 (オプション)
#
# [en]: #
# #### Step 4: Additional VSCode configuration (Optional)
#
# [zh]: #
# #### 第 4 步：附加 VSCode 配置(可选)

# %% [markdown]
# [ja]: #
# オススメの拡張機能にある`Ruff`はPythonのLintingツールで、自動的にコードを整形してくれます。
# VSCodeでは`.vscode/settings.json`に以下の設定を記載しておくと、ファイルを保存するたびに自動的にコードが整形されます。
#
# [en]: #
# `Ruff` is a linting tool for Python that automatically formats your code.
# By adding the following settings to `.vscode/settings.json`, the code will be automatically formatted whenever you save a file.
#
# [zh]: #
# `Ruff` 是 Python 的 linting 工具，可自动格式化您的代码。通过向 `.vscode/settings.json` 添加以下设置，每当您保存文件时，代码都会自动格式化。
#
# [END]: #
# ```javascript
# {
#     "notebook.output.wordWrap": true,
#     "[python]": {
#         "editor.formatOnSave": true,
#         "editor.codeActionsOnSave": {
#             "source.fixAll": "explicit",
#             "source.organizeImports": "explicit"
#         },
#         "editor.defaultFormatter": "charliermarsh.ruff"
#     },
#     "notebook.formatOnSave.enabled": true,
#     "notebook.codeActionsOnSave": {
#         "notebook.source.fixAll": "explicit",
#         "notebook.source.organizeImports": "explicit",
#     },
#     "jupyter.notebookFileRoot": "${fileDirname}",
# }
# ```
